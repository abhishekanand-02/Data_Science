# %%
import numpy as np

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
lower_fence
# Out:
# np.float64(1.5)

# %%
higher_fence
# Out:
# np.float64(141.5)

# %%
outliers=[]
for i in lst_marks:
    if i>= lower_fence or i<= higher_fence:
        print("This is not an outlier:",i)
    else:
        outliers.append(i)
# Out:
# This is not an outlier: -100
# This is not an outlier: -200
# This is not an outlier: 45
# This is not an outlier: 32
# This is not an outlier: 56
# This is not an outlier: 75
# This is not an outlier: 89
# This is not an outlier: 54
# This is not an outlier: 32
# This is not an outlier: 89
# This is not an outlier: 90
# This is not an outlier: 87
# This is not an outlier: 67
# This is not an outlier: 54
# This is not an outlier: 45
# This is not an outlier: 98
# This is not an outlier: 99
# This is not an outlier: 67
# This is not an outlier: 74
# This is not an outlier: 150
# This is not an outlier: 170
# This is not an outlier: 180

# %%
outliers
# Out:
# []

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,180]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
