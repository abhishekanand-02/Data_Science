# %% [markdown]
# ## Measure of Centeral Tendency

# %%
age = [12,23,34,32,67,86,78,35,70,71,77]

# %%
import numpy as np
np.mean(age)
# Out:
# np.float64(53.18181818181818)

# %%
weight = [45,56,67,78,89,90,34,23,45]
np.mean(weight)
# Out:
# np.float64(58.55555555555556)

# %%
import seaborn as sns
df  = sns.load_dataset('tips')

# %%
np.mean(df['total_bill'])
# Out:
# np.float64(19.78594262295082)

# %% [markdown]
# ### median

# %%
np.median(age)
# Out:
# np.float64(67.0)

# %%
age = [12,23,34,32,67,86,78,35,70,71,77,200]

# %%
np.mean(age)
# Out:
# np.float64(65.41666666666667)

# %%
np.median(age)
# Out:
# np.float64(68.5)
