# %% [markdown]
# ### STEP 1: Import Required Libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# C:\Users\abhishek.anand\AppData\Roaming\Python\Python313\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# ## Scenario : Next Word Prediction (Classic RNN use case)

# %% [markdown]
# ### Step 2: Sample text data

# %%
sentences = [
    "i love deep learning",
    "i love machine learning",
    "deep learning is powerful",
    "machine learning is useful"
]

# %% [markdown]
# ### Step 3: Convert Words into Numbers (Tokenization)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index
vocab_size = len(word_index) + 1

print(word_index)
# Out:
# {'learning': 1, 'i': 2, 'love': 3, 'deep': 4, 'machine': 5, 'is': 6, 'powerful': 7, 'useful': 8}

# %% [markdown]
# ### STEP 4: Create Input–Output Sequences

# %%
sequences = []

for sentence in sentences:
    token_list = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(token_list)):
        sequences.append(token_list[:i+1])

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %% [markdown]
# ### STEP 5: Padding (Make All Sequences Same Length)

# %%
max_len = max(len(seq) for seq in sequences)
sequences = pad_sequences(sequences, maxlen=max_len, padding='pre')

X = sequences[:, :-1]   # input words
y = sequences[:, -1]    # next word

# %% [markdown]
# ### STEP 6: Build the RNN Model

# %%
model = Sequential([
    Embedding(vocab_size, 10),
    SimpleRNN(64),
    Dense(vocab_size, activation='softmax')
])

# %% [markdown]
# ### STEP 7: Compile the Model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### STEP 8: Train the Model

# %%
model.fit(X, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.0000e+00 - loss: 2.2143
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0833 - loss: 2.2008
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1667 - loss: 2.1876
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2500 - loss: 2.1746
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4167 - loss: 2.1615
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 2.1483
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2500 - loss: 2.1348
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 2.1209
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2500 - loss: 2.1066
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3333 - loss: 2.0917
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3333 - loss: 2.0760
# Epoch 12/100
# ...

# %% [markdown]
# ### STEP 9: Predict the Next Word

# %%
def predict_next_word(text, model, tokenizer, max_len):
    token_list = tokenizer.texts_to_sequences([text])[0]
    token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')
    
    prediction = model.predict(token_list, verbose=0)
    predicted_index = prediction.argmax()
    
    for word, index in tokenizer.word_index.items():
        if index == predicted_index:
            return word

# %% [markdown]
# ### STEP 10: Test the Model

# %%
print(predict_next_word("i love", model, tokenizer, max_len))
print(predict_next_word("deep learning", model, tokenizer, max_len))
# Out:
# machine
# is
